# %% [markdown]
# # API Test
# Simple client to test our API.

# %%
import os
import requests

# %% [markdown]
# ## Dummy Linear regression model with only one feature

# %%
# running prediction (when APIs are up): regression lineaire
features = [1, 2]
url = "http://localhost:8000/linear_predict"
headers = {'accept': 'application/json'}
data = {"features": features}
response = requests.post(url, json=data, headers=headers)
response.json()
# Out:
# {'prediction': [[7.1098515671005345], [10.20224795870619]]}

# %% [markdown]
# ## Decision model on Iris dataset

# %%
# running prediction (when APIs are up): décision tree
# model to predict using iris dataset
features = [5.1, 3.5,1.4,0.2]
url = "http://localhost:8001/dt_predict"
headers = {'accept': 'application/json'}
data = {"features": features}
response = requests.post(url, json=data, headers=headers)
response.json()
# Out:
# {'prediction': 0}
